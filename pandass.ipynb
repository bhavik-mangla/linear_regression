# %%
import pandas as pd
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
import numpy as np

# %%
data = pd.read_csv('CarPrice_Assignment.csv')

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.','hellooo'], 'Sue': ['Pretty good.', 'Bland.','byeeee']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.
# 2        hellooo        byeeee

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
reviews = pd.read_csv("CarPrice_Assignment.csv", index_col=0)
reviews.shape
# Out:
# (205, 25)

# %%
reviews.head()
# Out:
#         symboling                   CarName fueltype aspiration doornumber  \
# car_ID
# 1               3        alfa-romero giulia      gas        std        two
# 2               3       alfa-romero stelvio      gas        std        two
# 3               1  alfa-romero Quadrifoglio      gas        std        two
# 4               2               audi 100 ls      gas        std       four
# 5               2                audi 100ls      gas        std       four
#
#             carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# car_ID                                                               ...
# 1       convertible        rwd          front       88.6      168.8  ...
# 2       convertible        rwd          front       88.6      168.8  ...
# 3         hatchback        rwd          front       94.5      171.2  ...
# 4             sedan        fwd          front       99.8      176.6  ...
# ...

# %%
reviews = pd.read_csv("CarPrice_Assignment.csv", index_col=0)
pd.set_option('max_rows', 10)

# %%
reviews
# Out:
#         symboling                   CarName fueltype aspiration doornumber  \
# car_ID
# 1               3        alfa-romero giulia      gas        std        two
# 2               3       alfa-romero stelvio      gas        std        two
# 3               1  alfa-romero Quadrifoglio      gas        std        two
# 4               2               audi 100 ls      gas        std       four
# 5               2                audi 100ls      gas        std       four
# ...           ...                       ...      ...        ...        ...
# 201            -1           volvo 145e (sw)      gas        std       four
# 202            -1               volvo 144ea      gas      turbo       four
# 203            -1               volvo 244dl      gas        std       four
# 204            -1                 volvo 246   diesel      turbo       four
# 205            -1               volvo 264gl      gas      turbo       four
#
# ...

# %%
reviews.CarName
# reviews['CarName']

# %%
reviews['CarName'][1]

# %%
reviews.iloc[1]

# %%
reviews.iloc[1:3, 1]

# %%
reviews.loc[:3, 'CarName']

# %%
reviews.loc[:, ['CarName', 'fueltype', 'carbody']]

# %%
#iloc uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded. So 0:10 will select entries 0,...,9. 
#loc, meanwhile, indexes inclusively. So 0:10 will select entries 0,...,10.

# %%
data[105:120].fueltype == 'gas'
# Out:
# 105     True
# 106     True
# 107     True
# 108    False
# 109     True
# 110    False
# 111     True
# 112    False
# 113     True
# 114    False
# 115     True
# 116    False
# 117     True
# 118     True
# 119     True
# Name: fueltype, dtype: bool

# %%
data[:20].loc[(data.fueltype == 'gas') & (data.enginesize >= 140),['CarName', 'fueltype', 'carbody']]
# Out:
#                      CarName fueltype    carbody
# 2   alfa-romero Quadrifoglio      gas  hatchback
# 12                    bmw x1      gas      sedan
# 13                    bmw x3      gas      sedan
# 14                    bmw z4      gas      sedan
# 15                    bmw x4      gas      sedan
# 16                    bmw x5      gas      sedan
# 17                    bmw x3      gas      sedan

# %%
data[30:40].loc[data.carbody.isin(['sedan', 'hatchback']),['CarName', 'fueltype', 'carbody']]
# Out:
#               CarName fueltype    carbody
# 30        honda civic      gas  hatchback
# 31   honda civic cvcc      gas  hatchback
# 32        honda civic      gas  hatchback
# 33  honda accord cvcc      gas  hatchback
# 34   honda civic cvcc      gas  hatchback
# 35    honda accord lx      gas      sedan
# 37       honda accord      gas  hatchback
# 38   honda civic 1300      gas  hatchback
# 39      honda prelude      gas      sedan

# %%
#reviews.loc[reviews.price.notnull()]
# isnull
#reviews['critic'] = 'everyone'   You can assign either a constant value:  or 
# reviews['index_backwards'] = range(len(reviews), 0, -1)       with an iterable of values:
